# %%
# Importing necessary modules
import copy
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import tensorflow as tf
import os
# %matplotlib inline
import cv2  # Import OpenCV for image processing
# !pip install opencv-python

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset_path = "/content/dataset-resized.zip"
# !unzip /content/dataset-resized.zip -d /content/data
# Out:
# unzip:  cannot find or open /content/dataset-resized.zip, /content/dataset-resized.zip.zip or /content/dataset-resized.zip.ZIP.

# %%
# base_dir = '/content/data'
# for folder_name in os.listdir(base_dir):
#     print(f"Folder: {trash}")
#     subfolder_path = os.path.join(base_dir, folder_name)
#     if os.path.isdir(subfolder_path):
#         for file_name in os.listdir(subfolder_path):
#             print(f"    File: {file_name}")

# %%
import os
import numpy as np
import tensorflow as tf

# Path to the "cardboard" subfolder
cardboard_folder_path = '/content/drive/MyDrive/Senior Year/Machine Learning/Final Project/dataset-resized/cardboard'

# Check if the folder exists
if os.path.exists(cardboard_folder_path) and os.path.isdir(cardboard_folder_path):
    cardboard = []
    for file_name in os.listdir(cardboard_folder_path):
        image_path = os.path.join(cardboard_folder_path, file_name)
        temp = tf.keras.preprocessing.image.load_img(
            path=image_path,
            color_mode='rgb',
            target_size=(227, 227)
        )
        X = np.array(temp)
        cardboard.append(X)

    cardboard = np.array(cardboard)
    cardboard = np.take(cardboard, np.random.permutation(cardboard.shape[0]), axis=0)
    print(cardboard.shape)
else:
    #print("The 'cardboard' folder does not exist or the path is incorrect.")
    cardboard_folder_path = '/content/drive/MyDrive/Junior Year/Machine Learning/Final Project/dataset-resized/cardboard'
    if os.path.exists(cardboard_folder_path) and os.path.isdir(cardboard_folder_path):
      cardboard = []
      for file_name in os.listdir(cardboard_folder_path):
        image_path = os.path.join(cardboard_folder_path, file_name)
        temp = tf.keras.preprocessing.image.load_img(
            path=image_path,
            color_mode='rgb',
            target_size=(227, 227)
            )
        X = np.array(temp)
        cardboard.append(X)

      cardboard = np.array(cardboard)
      cardboard = np.take(cardboard, np.random.permutation(cardboard.shape[0]), axis=0)
      print(cardboard.shape)
    else:
       print("The 'cardboard' folder does not exist or the path is incorrect.")
# Out:
# (403, 227, 227, 3)

# %%
# cardboard = []
# for i in range(1,404):
#     temp = tf.keras.preprocessing.image.load_img(
#         path = "/content/data/cardboard"+str(i)+".jpg",
#          color_mode='rgb',target_size=(227,227))
#     #grayscale=False,
#     X = np.array(temp)
#     cardboard.append(X)
# cardboard = np.array(cardboard)
# cardboard = np.take(cardboard,np.random.permutation(cardboard.shape[0]),axis=0)
# print(cardboard.shape)

# %%
# glass = []
# for i in range(1,502):
#     temp = tf.keras.preprocessing.image.load_img(
#         path = "trashnet/glass/glass"+str(i)+".jpg",
#          color_mode='rgb',target_size=(227,227))
#     X = np.array(temp)
#     glass.append(X)
# glass = np.array(glass)
# glass = np.take(glass,np.random.permutation(glass.shape[0]),axis=0)
# print(glass.shape)

# %%
# Path to the "glass" subfolder
glass_folder_path = '/content/drive/MyDrive/Senior Year/Machine Learning/Final Project/dataset-resized/glass'

# Check if the folder exists
if os.path.exists(glass_folder_path) and os.path.isdir(glass_folder_path):
    glass = []
    for file_name in os.listdir(glass_folder_path):
        image_path = os.path.join(glass_folder_path, file_name)
        temp = tf.keras.preprocessing.image.load_img(
            path=image_path,
            color_mode='rgb',
            target_size=(227, 227)
        )
        X = np.array(temp)
        glass.append(X)

    glass = np.array(glass)
    glass = np.take(glass, np.random.permutation(glass.shape[0]), axis=0)
    print(glass.shape)
else:
  glass_folder_path = '/content/drive/MyDrive/Junior Year/Machine Learning/Final Project/dataset-resized/glass'
  if os.path.exists(glass_folder_path) and os.path.isdir(glass_folder_path):
    glass = []
    for file_name in os.listdir(glass_folder_path):
        image_path = os.path.join(glass_folder_path, file_name)
        temp = tf.keras.preprocessing.image.load_img(
            path=image_path,
            color_mode='rgb',
            target_size=(227, 227)
        )
        X = np.array(temp)
        glass.append(X)

    glass = np.array(glass)
    glass = np.take(glass, np.random.permutation(glass.shape[0]), axis=0)
    print(glass.shape)
  else:
       print("The 'glass' folder does not exist or the path is incorrect.")
# Out:
# (501, 227, 227, 3)

# %%
# metal = []
# for i in range(1,411):
#     temp = tf.keras.preprocessing.image.load_img(
#         path = "trashnet/metal/metal"+str(i)+".jpg",
#      color_mode='rgb',target_size=(227,227))
#     X = np.array(temp)
#     metal.append(X)
# metal = np.array(metal)
# metal = np.take(metal,np.random.permutation(metal.shape[0]),axis=0)
# print(metal.shape)

# %%
import os
import numpy as np
import tensorflow as tf

# Path to the "Metal" subfolder
metal_folder_path = '/content/drive/MyDrive/Senior Year/Machine Learning/Final Project/dataset-resized/metal'

# Check if the folder exists
if os.path.exists(metal_folder_path) and os.path.isdir(metal_folder_path):
    metal = []
    for file_name in os.listdir(metal_folder_path):
        image_path = os.path.join(metal_folder_path, file_name)
        temp = tf.keras.preprocessing.image.load_img(
            path=image_path,
            color_mode='rgb',
            target_size=(227, 227)
        )
        X = np.array(temp)
        metal.append(X)

    metal = np.array(metal)
    metal = np.take(metal, np.random.permutation(metal.shape[0]), axis=0)
    print(metal.shape)
else:
  metal_folder_path = '/content/drive/MyDrive/Junior Year/Machine Learning/Final Project/dataset-resized/metal'
    #print("The 'metal' folder does not exist or the path is incorrect.")
  if os.path.exists(metal_folder_path) and os.path.isdir(metal_folder_path):
    metal = []
    for file_name in os.listdir(metal_folder_path):
        image_path = os.path.join(metal_folder_path, file_name)
        temp = tf.keras.preprocessing.image.load_img(
            path=image_path,
            color_mode='rgb',
            target_size=(227, 227)
        )
        X = np.array(temp)
        metal.append(X)

    metal = np.array(metal)
    metal = np.take(metal, np.random.permutation(metal.shape[0]), axis=0)
    print(metal.shape)
  else:
      print("The 'metal' folder does not exist or the path is incorrect.")
# Out:
# (410, 227, 227, 3)

# %%
# paper = []
# for i in range(1,595):
#     temp = tf.keras.preprocessing.image.load_img(
#         path = "trashnet/paper/paper"+str(i)+".jpg",
#          color_mode='rgb',target_size=(227,227))
#     X = np.array(temp)
#     paper.append(X)
# paper = np.array(paper)
# paper = np.take(paper,np.random.permutation(paper.shape[0]),axis=0)
# print(paper.shape)

# %%
import os
import numpy as np
import tensorflow as tf

# Path to the "Paper" subfolder
paper_folder_path = '/content/drive/MyDrive/Senior Year/Machine Learning/Final Project/dataset-resized/paper'

# Check if the folder exists
if os.path.exists(paper_folder_path) and os.path.isdir(paper_folder_path):
    paper = []
    for file_name in os.listdir(paper_folder_path):
        image_path = os.path.join(paper_folder_path, file_name)
        temp = tf.keras.preprocessing.image.load_img(
            path=image_path,
            color_mode='rgb',
            target_size=(227, 227)
        )
        X = np.array(temp)
        paper.append(X)

    paper = np.array(paper)
    paper = np.take(paper, np.random.permutation(paper.shape[0]), axis=0)
    print(paper.shape)
else:
  paper_folder_path = '/content/drive/MyDrive/Junior Year/Machine Learning/Final Project/dataset-resized/paper'
  #  print("The 'paper' folder does not exist or the path is incorrect.")
  if os.path.exists(paper_folder_path) and os.path.isdir(paper_folder_path):
    paper = []
    for file_name in os.listdir(paper_folder_path):
        image_path = os.path.join(paper_folder_path, file_name)
        temp = tf.keras.preprocessing.image.load_img(
            path=image_path,
            color_mode='rgb',
            target_size=(227, 227)
        )
        X = np.array(temp)
        paper.append(X)

    paper = np.array(paper)
    paper = np.take(paper, np.random.permutation(paper.shape[0]), axis=0)
    print(paper.shape)
  else:
      print("The 'paper' folder does not exist or the path is incorrect.")
# Out:
# (604, 227, 227, 3)

# %%
# plastic = []
# for i in range(1,483):
#     temp = tf.keras.preprocessing.image.load_img(
#         path = "trashnet/plastic/plastic"+str(i)+".jpg",
#          color_mode='rgb',target_size=(227,227))
#     X = np.array(temp)
#     plastic.append(X)
# plastic = np.array(plastic)
# plastic = np.take(plastic,np.random.permutation(plastic.shape[0]),axis=0)
# print(plastic.shape)

# %%
import os
import numpy as np
import tensorflow as tf

# Path to the "Plastic" subfolder
plastic_folder_path = '/content/drive/MyDrive/Senior Year/Machine Learning/Final Project/dataset-resized/plastic'

# Check if the folder exists
if os.path.exists(plastic_folder_path) and os.path.isdir(plastic_folder_path):
    plastic = []
    for file_name in os.listdir(plastic_folder_path):
        image_path = os.path.join(plastic_folder_path, file_name)
        temp = tf.keras.preprocessing.image.load_img(
            path=image_path,
            color_mode='rgb',
            target_size=(227, 227)
        )
        X = np.array(temp)
        plastic.append(X)

    plastic = np.array(plastic)
    plastic = np.take(plastic, np.random.permutation(plastic.shape[0]), axis=0)
    print(plastic.shape)
else:
  plastic_folder_path = '/content/drive/MyDrive/Junior Year/Machine Learning/Final Project/dataset-resized/plastic'
    #print("The 'plastic' folder does not exist or the path is incorrect.")
  if os.path.exists(plastic_folder_path) and os.path.isdir(plastic_folder_path):
      plastic = []
      for file_name in os.listdir(plastic_folder_path):
          image_path = os.path.join(plastic_folder_path, file_name)
          temp = tf.keras.preprocessing.image.load_img(
              path=image_path,
              color_mode='rgb',
              target_size=(227, 227) )
          X = np.array(temp)
          plastic.append(X)

      plastic = np.array(plastic)
      plastic = np.take(plastic, np.random.permutation(plastic.shape[0]), axis=0)
      print(plastic.shape)
  else:
      print("The 'plastic' folder does not exist or the path is incorrect.")
# Out:
# (482, 227, 227, 3)

# %%
# trash = []
# for i in range(1,138):
#     temp = tf.keras.preprocessing.image.load_img(
#         path = "trashnet/trash/trash"+str(i)+".jpg",
#          color_mode='rgb',target_size=(227,227))
#     X = np.array(temp)
#     trash.append(X)
# trash = np.array(trash)
# trash = np.take(trash,np.random.permutation(trash.shape[0]),axis=0)
# print(trash.shape)

# %%
import os
import numpy as np
import tensorflow as tf

# Path to the "Trash" subfolder
trash_folder_path = '/content/drive/MyDrive/Senior Year/Machine Learning/Final Project/dataset-resized/trash'

# Check if the folder exists
if os.path.exists(trash_folder_path) and os.path.isdir(trash_folder_path):
    trash = []
    for file_name in os.listdir(trash_folder_path):
        image_path = os.path.join(trash_folder_path, file_name)
        temp = tf.keras.preprocessing.image.load_img(
            path=image_path,
            color_mode='rgb',
            target_size=(227, 227)
        )
        X = np.array(temp)
        trash.append(X)

    trash = np.array(trash)
    trash = np.take(trash, np.random.permutation(trash.shape[0]), axis=0)
    print(trash.shape)
else:
  trash_folder_path = '/content/drive/MyDrive/Junior Year/Machine Learning/Final Project/dataset-resized/trash'
    #print("The 'trash' folder does not exist or the path is incorrect.")
  if os.path.exists(trash_folder_path) and os.path.isdir(trash_folder_path):
      trash = []
      for file_name in os.listdir(trash_folder_path):
          image_path = os.path.join(trash_folder_path, file_name)
          temp = tf.keras.preprocessing.image.load_img(
              path=image_path,
              color_mode='rgb',
              target_size=(227, 227)
          )
          X = np.array(temp)
          trash.append(X)

      trash = np.array(trash)
      trash = np.take(trash, np.random.permutation(trash.shape[0]), axis=0)
      print(trash.shape)
  else:
        print("The 'trash' folder does not exist or the path is incorrect.")
# Out:
# (137, 227, 227, 3)

# %%
print(f"Cardboard shape: {cardboard.shape}")
print(f"Glass shape: {glass.shape}")
print(f"Metal shape: {metal.shape}")
print(f"Paper shape: {paper.shape}")
print(f"Plastic shape: {plastic.shape}")
print(f"Trash shape: {trash.shape}")
# Out:
# Cardboard shape: (403, 227, 227, 3)
# Glass shape: (501, 227, 227, 3)
# Metal shape: (410, 227, 227, 3)
# Paper shape: (604, 227, 227, 3)
# Plastic shape: (482, 227, 227, 3)
# Trash shape: (137, 227, 227, 3)

# %%
train_X = np.vstack((cardboard[:302,:,:,:],glass[:376,:,:,:],metal[:307,:,:,:],
                    paper[:445,:,:,:],plastic[:361,:,:,:],trash[:103,:,:,:]))
test_X = np.vstack((cardboard[302:,:,:,:],glass[376:,:,:,:],metal[307:,:,:,:],
                   paper[445:,:,:,:],plastic[361:,:,:,:],trash[103:,:,:,:]))
train_Y = np.zeros((6,train_X.shape[0]))
test_Y = np.zeros((6,test_X.shape[0]))
for i in range(train_X.shape[0]):
    if(i<302):
        train_Y[0][i] = 1
    elif(i<678):
        train_Y[1][i] = 1
    elif(i<985):
        train_Y[2][i] = 1
    elif(i<1430):
        train_Y[3][i] = 1
    elif(i<1791):
        train_Y[4][i] = 1
    else:
        train_Y[5][i] = 1
for i in range(test_X.shape[0]):
    if(i<101):
        test_Y[0][i] = 1
    elif(i<226):
        test_Y[1][i] = 1
    elif(i<329):
        test_Y[2][i] = 1
    elif(i<478):
        test_Y[3][i] = 1
    elif(i<599):
        test_Y[4][i] = 1
    else:
        test_Y[5][i] = 1

# %%
train_X_aug = []
for i in range(train_X.shape[0]):
    tt = np.random.uniform(low = 10,high = 180)
    X1 = tf.keras.preprocessing.image.apply_affine_transform(train_X[i],theta = tt)
    #X2 = tf.keras.preprocessing.image.apply_affine_transform(train_X[i],theta = 180)
    train_X_aug.append(X1)
    #train_X_aug.append(X2)
train_X_aug = np.array(train_X_aug)
train_X_aug.shape
# Out:
# (1894, 227, 227, 3)

# %%
train_X = np.vstack((train_X_aug,train_X))
train_Y = np.vstack((train_Y.T,train_Y.T))
train_Y = train_Y.T
print(train_X.shape)
print(train_Y.shape)
# Out:
# (3788, 227, 227, 3)
# (6, 3788)

# %%
np.random.seed(1013)
train_perm = np.random.permutation(train_X.shape[0])
train_X = np.take(train_X,train_perm,axis=0)
print(train_X.shape)
train_Y = np.take(train_Y,train_perm,axis=1)
print(train_Y.shape)
np.random.seed(901)
test_perm = np.random.permutation(test_X.shape[0])
test_X = np.take(test_X,test_perm,axis=0)
print(test_X.shape)
test_Y = np.take(test_Y,test_perm,axis=1)
print(test_Y.shape)
# Out:
# (3788, 227, 227, 3)
# (6, 3788)
# (643, 227, 227, 3)
# (6, 643)

# %%
def AlexNet02(input_shape = (227, 227, 3), classes = 6):
    # Define the input as a tensor with shape input_shape
    X_input = tf.keras.Input(input_shape)


    # Zero-Padding
    #X = tf.keras.layers.ZeroPadding2D((3, 3))(X_input)
    X = X_input

    # Stage 1
    X = tf.keras.layers.Conv2D(96, (11, 11), strides = (4, 4), activation = "relu", name = 'conv1')(X)
    X = tf.keras.layers.MaxPooling2D((3, 3), strides=(2, 2))(X)
    X = tf.keras.layers.BatchNormalization(axis = 3, name = 'bn_conv1')(X)

    # Stage 2
    #X = tf.keras.layers.Conv2D(256, (5, 5), padding = "same",activation = "relu", name = 'conv2')(X)
    #X = tf.keras.layers.MaxPooling2D((3, 3), strides=(2, 2))(X)
    #X = tf.keras.layers.BatchNormalization(axis = 3, name = 'bn_conv2')(X)
    #X = tf.keras.layers.Conv2D(384, (3, 3), padding = "same",activation = "relu", name = 'conv3')(X)
    #X = tf.keras.layers.Conv2D(384, (3, 3), padding = "same",activation = "relu", name = 'conv4')(X)
    #X = tf.keras.layers.Conv2D(256, (3, 3), padding = "same",activation = "relu", name = 'conv5')(X)
    #X = tf.keras.layers.MaxPooling2D((3, 3), strides=(2, 2))(X)
    X = tf.keras.layers.Flatten()(X)
    #X = tf.keras.layers.Dropout(0.5)(X)
    X = tf.keras.layers.Dense(4096, activation = "relu", name='fc' + str(1))(X)
    #X = tf.keras.layers.Dropout(0.5)(X)
    X = tf.keras.layers.Dense(4096, activation = "relu", name='fc' + str(2))(X)
    X = tf.keras.layers.Dense(classes, activation='softmax', name='fc' + str(classes))(X)


    # Create model
    model = tf.keras.Model(inputs = X_input, outputs = X, name='ALEXNET_Test1')

    return model

# %%
model = AlexNet02()
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.000005), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_X, train_Y.T, epochs = 40, batch_size = 32)
# Out:
# Epoch 1/40
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 20s 99ms/step - accuracy: 0.3763 - loss: 1.6335
# Epoch 2/40
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - accuracy: 0.7240 - loss: 0.8080
# Epoch 3/40
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.7932 - loss: 0.6240
# Epoch 4/40
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.8060 - loss: 0.5575
# Epoch 5/40
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 8s 68ms/step - accuracy: 0.8089 - loss: 0.5455
# Epoch 6/40
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.8316 - loss: 0.4781
# Epoch 7/40
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8418 - loss: 0.4533
# Epoch 8/40
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.8483 - loss: 0.4268
# Epoch 9/40
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.8395 - loss: 0.4397
# Epoch 10/40
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8374 - loss: 0.4280
# Epoch 11/40
# ...

# %%
plt.plot(history.history["accuracy"])
plt.title("Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.show()
plt.plot(history.history["loss"])
plt.title("Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

# %%
preds = model.evaluate(test_X, test_Y.T)

test_loss = preds[0]
test_accuracy = preds[1]
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))
validation_loss = history.history['val_loss']
validation_accuracy = history.history['val_accuracy']
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6146 - loss: 1.8508
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-4d38ecf28595> in <cell line: 2>()
#       1 preds = model.evaluate(test_X, test_Y.T)
# ----> 2 history = model.fit(validation_data=(test_X, test_Y.T))
#       3
#       4 test_loss = preds[0]
#       5 test_accuracy = preds[1]
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/data_adapter_utils.py in <genexpr>(.0)
#     101
# ...

# %%
plt.plot(history.history['test_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

plt.plot(history.history['test_loss'])
plt.title('Model accuracy')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.show()

# %%
model.summary()

# %%
import random

def load_images_from_folder(folder_path, num_images=5):
    """Load a specified number of images from a folder."""
    if os.path.exists(folder_path) and os.path.isdir(folder_path):
        files = os.listdir(folder_path)
        selected_files = files[:5]   # select first five photos
        images = []
        for file_name in selected_files:
            image_path = os.path.join(folder_path, file_name)
            temp = tf.keras.preprocessing.image.load_img(
                path=image_path,
                color_mode='rgb',
                target_size=(227, 227)
            )
            images.append(np.array(temp))
        return np.array(images)
    else:
        print(f"The folder '{folder_path}' does not exist or the path is incorrect.")
        return None

# Load 5 images from each folder
cardboard_images = load_images_from_folder(cardboard_folder_path)
glass_images = load_images_from_folder(glass_folder_path)
metal_images = load_images_from_folder(metal_folder_path)
paper_images = load_images_from_folder(paper_folder_path)
plastic_images = load_images_from_folder(plastic_folder_path)
trash_images = load_images_from_folder(trash_folder_path)

# Check if images are loaded
print(f"Cardboard images loaded: {len(cardboard_images)}")
print(f"Glass images loaded: {len(glass_images)}")
print(f"Metal images loaded: {len(metal_images)}")
print(f"Paper images loaded: {len(paper_images)}")
print(f"Plastic images loaded: {len(plastic_images)}")
print(f"Trash images loaded: {len(trash_images)}")

# Combine all selected images into a single array
selected_images = np.vstack((cardboard_images, glass_images, metal_images,
                             paper_images, plastic_images, trash_images))

# Display one of the loaded images for verification
plt.imshow(selected_images[0] / 255)  # Scale to [0, 1]
plt.axis('off')
plt.title("Example Loaded Image")
plt.show()

# %%
def grad_cam(model, image, class_idx):
    """Generates a heat map using Grad-CAM."""
    print(f"Inside grad_cam, image shape: {image.shape}")

    # Expand dimensions of the image to match input shape
    image = np.expand_dims(image, axis=0)  # Ensure batch dimension is included

    # Get the gradient model
    grad_model = tf.keras.Model(
        inputs=[model.inputs], outputs=[model.get_layer("conv1").output, model.output]
    )

    with tf.GradientTape() as tape:
        last_conv_layer = model.get_layer('conv1')  # Ensure this matches your model's last conv layer
        iterate = tf.keras.models.Model([model.input], [last_conv_layer.output, model.output])

        # Use the already expanded image
        conv_outputs, preds = iterate(image)  # Image is now (1, 227, 227, 3)
        loss = preds[:, class_idx]

    grads = tape.gradient(loss, conv_outputs)[0]
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1))  # Average over the spatial dimensions

    # Convert the conv_outputs to NumPy array
    heatmap = conv_outputs[0].numpy()  # Convert to NumPy array for manipulation

    print(f"Shape of pooled_grads: {pooled_grads.shape}")  # Debugging line
    print(f"Shape of heatmap before scaling: {heatmap.shape}")  # Debugging line

    # Ensure pooled_grads is a numpy array
    pooled_grads = pooled_grads.numpy()  # Convert to NumPy for manipulation
    pooled_grads = np.expand_dims(pooled_grads, axis=(0, 1))  # Shape becomes (1, 1, 256)

    # Check shapes before multiplication
    print(f"Shape of pooled_grads after expansion: {pooled_grads.shape}")  # Debugging line
    print(f"Shape of heatmap before applying pooled_grads: {heatmap.shape}")  # Debugging line

    # Multiply each channel in the heatmap with the corresponding pooled gradient
    # Ensure correct dimensions for multiplication
    heatmap = np.tensordot(heatmap, pooled_grads, axes=(2, 2))  # Shape will be (13, 13)

    heatmap = np.maximum(heatmap, 0)  # Ensure non-negative values
    heatmap /= np.max(heatmap)  # Normalize to [0, 1]

    # Squeeze the heatmap
    heatmap = np.squeeze(heatmap)  # Remove dimensions of size 1

    # Check heatmap shape before resizing
    print(f"Heatmap shape before resizing: {heatmap.shape}")

    # Resize heatmap to match the input image dimensions
    if heatmap.ndim == 2:  # Ensure the heatmap is 2D
        heatmap = cv2.resize(heatmap, (image.shape[2], image.shape[1]))  # Adjust to your image shape
    else:
        raise ValueError("Heatmap does not have the expected shape for resizing.")

    return heatmap

# %%
def display_grad_cam(image, heatmap):
    # Resize heatmap to match the original image size
    heatmap = np.uint8(255 * heatmap)  # Scale to 0-255
    heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)  # Apply color map

    # Overlay the heatmap on the original image
    superimposed_img = heatmap * 0.4 + image  # Adjust alpha as needed
    plt.imshow(superimposed_img / 255.0)  # Display as float image
    plt.axis('off')
    plt.show()

# Run Grad-CAM on the selected images
print(f"Number of selected images: {len(selected_images)}")  # Debug statement

for idx, selected_image in enumerate(selected_images):
    print(f"Selected image {idx} shape: {selected_image.shape}")  # Debug statement

    # Check if the loop is entering the body
    if selected_image is None:
        print(f"Image {idx} is None.")  # Check for None
        continue  # Skip if None

    # Ensure we expand the dimensions correctly for the model
    expanded_image = np.expand_dims(selected_image, axis=0)
    print(f"After expansion, expanded image shape: {expanded_image.shape}")

    # Predict class using the model
    class_idx = np.argmax(model.predict(expanded_image))
    print(f"Image {idx}: Predicted class index: {class_idx}")

    # Call Grad-CAM
    print(f"Calling grad_cam for image {idx} with class index {class_idx}")
    heatmap = grad_cam(model, np.squeeze(selected_image), class_idx)  # Remove extra dimensions
    display_grad_cam(selected_image, heatmap)

# %%
# Test with a single image
test_image = selected_images[0]
class_idx = np.argmax(model.predict(np.expand_dims(test_image, axis=0)))
heatmap = grad_cam(model, test_image, class_idx)
display_grad_cam(test_image, heatmap)
